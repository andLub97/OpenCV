# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("arvore.jpg", cv2.IMREAD_REDUCED_COLOR_2)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x7F531FA45050>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=640x427 at 0x7F531E0E3210>

# %%
blur_image = cv2.GaussianBlur(image, (27, 27), 0)
cv2_imshow(blur_image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x7F53159ECCD0>

# %%
#filtro sépia
filtroSep = np.array([[0.272, 0.534, 0.131],
                   [0.349, 0.686, 0.168],
                   [0.393, 0.769, 0.189]])
sepia_image = cv2.filter2D(image, -1, filtroSep)
cv2_imshow(sepia_image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x7F531585A910>

# %%
inv_gray_image = 255 - gray_image
cv2_imshow(inv_gray_image)
# Out:
# <PIL.Image.Image image mode=L size=640x427 at 0x7F531588D990>

# %%
blur_image = cv2.GaussianBlur(inv_gray_image, (21, 21), 0, 0)
cv2_imshow(blur_image)
# Out:
# <PIL.Image.Image image mode=L size=640x427 at 0x7F531581AAD0>
